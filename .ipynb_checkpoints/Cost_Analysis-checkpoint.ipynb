# %%
import numpy as np
import pandas as pd
import os

# %%
#enter file name here
file_name = "2-18-436_jan.xls"

# %%
DATA_PATH = os.path.join(os.getcwd(),"data")
data = pd.read_excel(os.path.join(DATA_PATH, file_name))

# %%
#clean data by chopping off rows
def clean_data(input):
    new_index = input.reset_index() #add index row
    new_header = new_index.iloc[1] #identify a new header
    new_data = new_index[2:] #chop off top two rows
    new_data_index = new_data.reset_index(drop=True) #reset again
    new_data_clean = new_data_index.fillna('') #drop nan
    new_data_clean.columns = new_header

    return new_data_clean

# %%
#load data into the function
df = clean_data(data)
df.head()
# Out:
# 1 Extra Cost Code              Description Cat       Date Ref 1  \
# 0           1-323  BBI Warehouse Materials   O 2018-11-21
# 1           1-323  BBI Warehouse Materials   O 2018-11-21
# 2           1-323  BBI Warehouse Materials   O 2018-11-12
# 3           1-323  BBI Warehouse Materials   O 2018-11-12
# 4           1-323  BBI Warehouse Materials   O 2018-11-12
#
# 1            Description Ref 2  Units   Cost  Amount Application       Date  \
# 0              Spill Kit          2.0  57.96  115.92          JC 2018-11-30
# 1    Gloves, Cut Level 4          6.0   4.35   26.10          JC 2018-11-30
# 2   Batteries "AA" (4pk)          6.0   4.84   29.04          JC 2018-11-30
# 3      10' Sling Endless          2.0  49.89   99.78          JC 2018-11-30
# 4  Safety Vest FR - L/XL          6.0  87.12  522.72          JC 2018-11-30
#
# 1      Stamp Description NaN
# 0 2018-12-03
# 1 2018-12-03
# 2 2018-12-03
# 3 2018-12-03
# 4 2018-12-03

# %%
#sum by cost code and extra
df.groupby(['Cost Code', 'Extra']).sum().head()
# Out:
# 1                Units         Cost    Amount
# Cost Code Extra
# 1-002     1.I06  861.0  3605.176604  92182.14
#           1.I07  570.0  1621.320833  53401.34
# 1-003     1.I14  543.0  1032.502053  25782.10
#           1.I15  546.0   688.827786  29001.36
# 1-009     1.I20   22.0   559.430833   1354.38

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def chart(input):
    new_frame = input[['Stamp','Amount']].copy() #timestamp + amount
    new_index = new_frame.set_index(pd.DatetimeIndex(new_frame['Stamp'])) #reset index
    month = new_index.resample('M').sum() #sum by month
    month_index = month.reset_index() #reset again
    date = month_index['Stamp']
    amount = month_index['Amount'] 
    plt.bar(date, amount, 20)
    plt.show()
    
    #return month_index

# %%
chart(df)

# %%
def cost_period(input):
    new_frame = input[['Stamp','Amount', 'Cost Code', 'Extra', 'Description']].copy() #timestamp + amount
    new_index = new_frame.set_index(pd.DatetimeIndex(new_frame['Stamp'])) #reset index
    month = new_index.loc['2018-09-24 01:00:00':'2019-1-31 04:00:00']

    
    return new_index.head()

# %%
cost_period(df)
# Out:
# 1               Stamp  Amount Cost Code Extra              Description  \
# Stamp
# 2018-12-03 2018-12-03  115.92     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   26.10     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   29.04     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   99.78     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03  522.72     1-323        BBI Warehouse Materials
#
# 1                     Description Description
# Stamp
# 2018-12-03              Spill Kit
# 2018-12-03    Gloves, Cut Level 4
# 2018-12-03   Batteries "AA" (4pk)
# 2018-12-03      10' Sling Endless
# 2018-12-03  Safety Vest FR - L/XL

# %%
new_frame = df[['Stamp','Amount', 'Cost Code', 'Extra', 'Description']].copy() #timestamp + amount
new_index = new_frame.set_index(pd.DatetimeIndex(new_frame['Stamp'])) #reset index

# %%
new_index.head()
# Out:
# 1               Stamp  Amount Cost Code Extra              Description  \
# Stamp
# 2018-12-03 2018-12-03  115.92     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   26.10     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   29.04     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03   99.78     1-323        BBI Warehouse Materials
# 2018-12-03 2018-12-03  522.72     1-323        BBI Warehouse Materials
#
# 1                     Description Description
# Stamp
# 2018-12-03              Spill Kit
# 2018-12-03    Gloves, Cut Level 4
# 2018-12-03   Batteries "AA" (4pk)
# 2018-12-03      10' Sling Endless
# 2018-12-03  Safety Vest FR - L/XL

# %%
total_cost = df['Amount'].sum()

# %%
#contract_amount = 1445727
contract_amount = 7850000
margin = contract_amount - total_cost
percentage = margin/contract_amount
print(total_cost)
print(margin)
print(percentage.round(3))
# Out:
# 3351682.76
# 4498317.24
# 0.573

# %%
january = new_index.loc['2018-12-24 01:00:00':'2019-01-27 04:00:00']
january.head()
# Out:
# 1               Stamp  Amount Cost Code Extra              Description  \
# Stamp
# 2019-01-07 2019-01-07   60.24     1-323        BBI Warehouse Materials
# 2019-01-07 2019-01-07   26.52     1-323        BBI Warehouse Materials
# 2019-01-07 2019-01-07   86.68     1-323        BBI Warehouse Materials
# 2019-01-07 2019-01-07   12.10     1-323        BBI Warehouse Materials
# 2019-01-07 2019-01-07    6.14     1-323        BBI Warehouse Materials
#
# 1                              Description Description
# Stamp
# 2019-01-07           Glasses, Clear Safety
# 2019-01-07           Glasses, Amber Shaded
# 2019-01-07   Husky Contractor Bags - 50 ct
# 2019-01-07            Duct Tape (3M Brand)
# 2019-01-07  Winter Gloves, Orange Pwr Ther

# %%
january['Amount'].sum()
# Out:
# 1892494.6400000001

# %%
jan_codes = january.groupby(['Cost Code', 'Extra']).sum()
jan_codes
# Out:
# 1                        Amount
# Cost Code Extra
# 1-002     1.I06        30662.42
#           1.I07        23264.72
# 1-003     1.I14        10862.55
#           1.I15        12441.67
# 1-009     1.I20          252.81
# 1-010     1.I18         1050.57
# 1-011     1.I08        45689.19
#           FUEL         13964.89
# 1-012     1.I12        44975.17
# 1-015     1.I16        44782.00
# 1-040     1.104000      2049.11
#           1.I02         4841.55
# 1-050     1.ID2000     29421.17
# 1-140     1.102        35301.06
# 1-205     1.28000        433.81
#           1.I22         8231.96
#           1.I26        53984.98
# 1-250     1.I38        38721.83
# 1-305     1.1355        7026.12
# 1-323                    437.68
# 1-325                   5089.85
# 1-445     1.888        41640.00
# 1-450     1.I30         2746.83
#           1.I30.1003     432.00
# 2-001     2.2201.100   89451.87
# 3-010     3.3102       24000.12
# 3-011     3.3.1         4820.27
#           3.3013         320.00
#           3.302       217998.73
# 3-020     5.32        173212.35
# 3-030     3.332        19630.83
#           6.3332        4433.21
# 31-001    1.I34         7057.74
# 31-023    2.2201       57489.24
#           2.401        16692.26
#           2.402       131504.74
#           2.403        40149.98
#           6.2205       87043.91
# 31-025    1.101          335.87
#           1.105          426.50
# 31-032    2.2208       21105.85
#           2.2211       63077.40
#           2.4531      157125.56
# 33-041    2.412        99928.46
#           2.4141        9221.45
#           2.4172       96199.28
#           2.4240.1      1625.21
# 33-056    22.550       61502.43
#           4.5000.2      4823.75
